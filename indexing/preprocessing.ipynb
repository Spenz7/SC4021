# %%
import pandas as pd

# %%
df = pd.read_csv('combined.csv')
url_pattern = r'^(http|https)://\S+|www\.\S+$'
df_clean = df[~df['text'].str.match(url_pattern, na=False)]
df_clean.to_csv('cleaned_data.csv', index=False, encoding='utf-8')
print(f"Removed {len(df) - len(df_clean)} rows containing only links.")

# %%
# df = pd.read_csv('88kTrainingData_sentiment.csv')
# url_pattern = r'^(http|https)://\S+|www\.\S+$'
# df_clean = df[~df['text'].str.match(url_pattern, na=False)]
# df_clean.to_csv('cleaned_data_sentiment.csv', index=False, encoding='utf-8')
# print(f"Removed {len(df) - len(df_clean)} rows containing only links.")
# Out:
# Removed 356 rows containing only links.

# %%
# df = pd.read_csv('reddit_crawled.csv', encoding='cp1252')
# url_pattern = r'^(http|https)://\S+|www\.\S+$'
# df_clean = df[~df['text'].str.match(url_pattern, na=False)]
# df_clean.to_csv('cleaned_data.csv', index=False, encoding='utf-8')
# print(f"Removed {len(df) - len(df_clean)} rows containing only links.")
